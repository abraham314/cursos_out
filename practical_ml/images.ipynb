# %%
# import libraries 
import pandas as pd # Import Pandas for data manipulation using dataframes
import numpy as np # Import Numpy for data statistical analysis 
import matplotlib.pyplot as plt # Import matplotlib for data visualisation
import seaborn as sns
import random
# %matplotlib inline

# %%
from PIL import Image

im = Image.open('piedra.jpg') # Can be many different formats.
pix = im.load()
print(im.size)  # Get the width and hight of the image for iterating over
#print(pix[x,y])  # Get the RGBA Value of the a pixel of an image
#pix[x,y] = value  # Set the RGBA Value of the image (tuple)
im.save('piedra.png')  # Save the modified pixels as .png
# Out:
# (4128, 2322)

# %%
pix[0,0]
# Out:
# (254, 254, 252)

# %%
print(418*2322)
print(255*255*255)
# Out:
# 970596
# 16581375

# %%
imp = Image.open('piedra.png') # Can be many different formats.

# %%
imp.size
# Out:
# (4128, 2322)

# %%
img = Image.open("piedra.png").convert('L')
arr = np.array(img)
arr.shape
# Out:
# (2322, 4128)

# %%
arr.shape
plt.imshow(arr)

# %%
arr2=arr[0:,456:456+28]
plt.imshow(arr2)

# %%
413*232/(28*28)
# Out:
# 122.21428571428571

# %%
#from PIL import Image

basewidth = 784
img = Image.open('piedra.jpg')
wpercent = (basewidth/float(img.size[0]))
hsize = int((float(img.size[1])*float(wpercent)))
img = img.resize((basewidth,hsize), Image.ANTIALIAS)
img.save('piedra.jpg')

# %%
img = Image.open("piedra.jpg").convert('L')
arr = np.array(img)
arr.shape
# Out:
# (420, 784)

# %%
plt.imshow(arr)

# %%
from PIL import Image

img = Image.open('piedra.jpg') # image extension *.png,*.jpg
new_width  = 28
new_height = 28
img = img.resize((new_width, new_height), Image.ANTIALIAS)
img.save('piedra.png') # format may what u want ,*.png,*jpg,*.gif

# %%
img = Image.open("piedra.png").convert('L')
arr = np.array(img)
arr.shape
# Out:
# (28, 28)

# %%
plt.imshow(arr)

# %%
from scipy.ndimage.filters import convolve
from scipy.signal import convolve2d
from scipy import misc

# %%
h_kernel = np.array([[ 1,  2,  1],
                     [ 0,  0,  0],
                     [-1, -2, -1]])

# %%
plt.imshow(h_kernel, cmap='gray')

# %%
res = convolve2d(img, h_kernel)

plt.imshow(res, cmap='gray')
